# %%
# %matplotlib inline

# %%
from pylab import *
import PIL

# %%
vixie = PIL.Image.open("Vixie.jpg")

# %%
im = array(vixie)
im3 = 255 - array(vixie)
im4 = (127./255.) * array(vixie) + 1
imshow(random_integers(0,255,(400, 300, 3)))

# %%
imshow(array(vixie.crop((100,100,1400,1400)).rotate(45)))

# %%
im = array(vixie.convert('L'))
figure()
gray()
contour(im, origin='image')
axis('equal')
axis('off')
# Out:
# (0.0, 4000.0, 0.0, 3000.0)

# %%
figure()
hist(im.flatten(), 128)
show()

# %%
imshow(255-im)
print("please click 3 points")
#x =  ginput(3)
#print("you clicked:", x)
show()
# Out:
# please click 3 points

# %%
print im.shape, im.dtype
array(vixie).shape, array(vixie).dtype
# Out:
# (3000, 4000) uint8
# ((3000, 4000, 3), dtype('uint8'))

# %%
def histeq(im,nbr_bins=256):
    """ Histogram equalization of a grayscale image. """
    # get image histogram
    imhist,bins = histogram(im.flatten(),nbr_bins,normed=True)
    cdf = imhist.cumsum() # cumulative distribution function
    cdf = 255 * cdf / cdf[-1] # normalize

    # use linear interpolation of cdf to find new pixel values
    im2 = interp(im.flatten(),bins[:-1],cdf)
    
    return im2.reshape(im.shape), cdf

# %%
imh, cdf = histeq(im)
#display(imshow(im))
imshow(im)

# %%
sqrt(16*16+9*9)/16.*115
# Out:
# 131.94496070805434
